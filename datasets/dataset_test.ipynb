# %%
from test_dataset import CityScapeTestDataset

# %%
test_dataset = CityScapeTestDataset()

# %%
pic = test_dataset[0][0]
label = test_dataset[0][1]

# %%
print(pic.shape)
print(label.shape)
# Out:
# torch.Size([3, 1024, 2048])
# torch.Size([1, 1024, 2048])

# %%
import torch
import numpy
import matplotlib.pyplot as plt

# %%
plt.imshow(numpy.transpose(pic.numpy(),[1,2,0]))
plt.show()
plt.imshow(numpy.transpose(label.numpy(),[1,2,0]).reshape(1024,2048))
plt.show()
print(label)
# Out:
# tensor([[[3, 3, 3,  ..., 3, 3, 3],
#          [3, 3, 3,  ..., 3, 3, 3],
#          [3, 3, 3,  ..., 3, 3, 3],
#          ...,
#          [3, 3, 3,  ..., 3, 3, 3],
#          [3, 3, 3,  ..., 3, 3, 3],
#          [3, 3, 3,  ..., 3, 3, 3]]], dtype=torch.int32)

# %%
from torch.utils.data import DataLoader
test_dataloader = DataLoader(test_dataset, batch_size=12, shuffle=True, num_workers=2)

# %%
img,labels = next(iter(test_dataloader))

# %%
img.shape
# Out:
# torch.Size([12, 3, 1024, 2048])

# %%
labels.shape
# Out:
# torch.Size([12, 1, 1024, 2048])

# %%
torch.max(labels)
# Out:
# tensor(3, dtype=torch.int32)

# %%
torch.min(labels)
# Out:
# tensor(0, dtype=torch.int32)
